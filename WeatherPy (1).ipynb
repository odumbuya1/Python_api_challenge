# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 596

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]
        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
    # If an error is experienced, skip the city
    except Exception as e:
       print (e)
# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vadso
# 'coord'
# Processing Record 2 of Set 1 | taoudenni
# 'coord'
# Processing Record 3 of Set 1 | edinburgh of the seven seas
# 'coord'
# Processing Record 4 of Set 1 | blackmans bay
# 'coord'
# Processing Record 5 of Set 1 | kingaroy
# 'coord'
# Processing Record 6 of Set 1 | port-aux-francais
# 'coord'
# Processing Record 7 of Set 1 | nabire
# 'coord'
# Processing Record 8 of Set 1 | susuman
# 'coord'
# Processing Record 9 of Set 1 | minas de marcona
# 'coord'
# Processing Record 10 of Set 1 | udachny
# 'coord'
# Processing Record 11 of Set 1 | winnemucca
# 'coord'
# Processing Record 12 of Set 1 | barra de santo antonio
# 'coord'
# Processing Record 13 of Set 1 | iqaluit
# 'coord'
# Processing Record 14 of Set 1 | invercargill
# 'coord'
# Processing Record 15 of Set 1 | atafu village
# 'coord'
# Processing Record 16 of Set 1 | sonamukhi
# 'coord'
# Processing Record 17 of Set 1 | al fuwayliq
# 'coord'
# Processing Record 18 of Set 1 | albany
# 'coord'
# Processing Record 19 of Set 1 | maasim
# 'coord'
# Processing Record 20 of Set 1 | iskateley
# 'coord'
# Processing Record 21 of Set 1 | asahi
# 'coord'
# Processing Record 22 of Set 1 | ribeira grande
# 'coord'
# Processing Record 23 of Set 1 | tazovsky
# 'coord'
# Processing Record 24 of Set 1 | hamilton
# 'coord'
# Processing Record 25 of Set 1 | sisimiut
# 'coord'
# Processing Record 26 of Set 1 | sao joao da barra
# 'coord'
# Processing Record 27 of Set 1 | waitangi
# 'coord'
# Processing Record 28 of Set 1 | charlottetown
# 'coord'
# Processing Record 29 of Set 1 | tiksi
# 'coord'
# Processing Record 30 of Set 1 | dien bien phu
# 'coord'
# Processing Record 31 of Set 1 | grytviken
# 'coord'
# Processing Record 32 of Set 1 | nicoya
# 'coord'
# Processing Record 33 of Set 1 | whitehorse
# 'coord'
# Processing Record 34 of Set 1 | colonia menno
# 'coord'
# Processing Record 35 of Set 1 | kapa'a
# 'coord'
# Processing Record 36 of Set 1 | grand falls-windsor
# 'coord'
# Processing Record 37 of Set 1 | djibo
# 'coord'
# Processing Record 38 of Set 1 | lionel town
# 'coord'
# Processing Record 39 of Set 1 | cannonvale
# 'coord'
# Processing Record 40 of Set 1 | adamstown
# 'coord'
# Processing Record 41 of Set 1 | saint-pierre
# 'coord'
# Processing Record 42 of Set 1 | hailey
# 'coord'
# Processing Record 43 of Set 1 | lethem
# 'coord'
# Processing Record 44 of Set 1 | suntar
# 'coord'
# Processing Record 45 of Set 1 | olonkinbyen
# 'coord'
# Processing Record 46 of Set 1 | mersa matruh
# 'coord'
# Processing Record 47 of Set 1 | alaghsas
# 'coord'
# Processing Record 48 of Set 1 | yamada
# 'coord'
# Processing Record 49 of Set 1 | hawaiian paradise park
# 'coord'
# Processing Record 50 of Set 1 | tanjung selor
# 'coord'
# Processing Record 0 of Set 2 | troy
# 'coord'
# Processing Record 1 of Set 2 | georgetown
# 'coord'
# Processing Record 2 of Set 2 | nogliki
# 'coord'
# Processing Record 3 of Set 2 | jamestown
# 'coord'
# Processing Record 4 of Set 2 | fort mcmurray
# 'coord'
# Processing Record 5 of Set 2 | gdov
# 'coord'
# Processing Record 6 of Set 2 | happy valley-goose bay
# 'coord'
# Processing Record 7 of Set 2 | holualoa
# 'coord'
# Processing Record 8 of Set 2 | petropavlovka
# 'coord'
# Processing Record 9 of Set 2 | bilibino
# 'coord'
# Processing Record 10 of Set 2 | ushuaia
# 'coord'
# Processing Record 11 of Set 2 | ilulissat
# 'coord'
# Processing Record 12 of Set 2 | la'ie
# 'coord'
# Processing Record 13 of Set 2 | egilsstadir
# 'coord'
# Processing Record 14 of Set 2 | manokwari
# 'coord'
# Processing Record 15 of Set 2 | yellowknife
# 'coord'
# Processing Record 16 of Set 2 | newnham
# 'coord'
# Processing Record 17 of Set 2 | 'ohonua
# 'coord'
# Processing Record 18 of Set 2 | terekeka
# 'coord'
# Processing Record 19 of Set 2 | papao
# 'coord'
# Processing Record 20 of Set 2 | nieuw amsterdam
# 'coord'
# Processing Record 21 of Set 2 | oguz
# 'coord'
# Processing Record 22 of Set 2 | halifax
# 'coord'
# Processing Record 23 of Set 2 | ninghai
# 'coord'
# Processing Record 24 of Set 2 | stanley
# 'coord'
# Processing Record 25 of Set 2 | puerto natales
# 'coord'
# Processing Record 26 of Set 2 | makokou
# 'coord'
# Processing Record 27 of Set 2 | salekhard
# 'coord'
# Processing Record 28 of Set 2 | kone
# 'coord'
# Processing Record 29 of Set 2 | thompson
# 'coord'
# Processing Record 30 of Set 2 | wailua homesteads
# 'coord'
# Processing Record 31 of Set 2 | kapuskasing
# 'coord'
# Processing Record 32 of Set 2 | paraiso
# 'coord'
# Processing Record 33 of Set 2 | baardheere
# 'coord'
# Processing Record 34 of Set 2 | puerto ayora
# 'coord'
# Processing Record 35 of Set 2 | santa elena de uairen
# 'coord'
# Processing Record 36 of Set 2 | masterton
# 'coord'
# Processing Record 37 of Set 2 | gerash
# 'coord'
# Processing Record 38 of Set 2 | portland
# 'coord'
# Processing Record 39 of Set 2 | ponta delgada
# 'coord'
# Processing Record 40 of Set 2 | rikaze
# 'coord'
# Processing Record 41 of Set 2 | tranovaho
# 'coord'
# Processing Record 42 of Set 2 | anadyr
# 'coord'
# Processing Record 43 of Set 2 | williamson
# 'coord'
# Processing Record 44 of Set 2 | port alfred
# 'coord'
# Processing Record 45 of Set 2 | kingston
# 'coord'
# Processing Record 46 of Set 2 | lihue
# 'coord'
# Processing Record 47 of Set 2 | isafjordur
# 'coord'
# Processing Record 48 of Set 2 | kirkwall
# 'coord'
# Processing Record 49 of Set 2 | tomatlan
# 'coord'
# Processing Record 0 of Set 3 | avanigadda
# 'coord'
# Processing Record 1 of Set 3 | polyarnyy
# 'coord'
# Processing Record 2 of Set 3 | point pedro
# 'coord'
# Processing Record 3 of Set 3 | lebu
# 'coord'
# Processing Record 4 of Set 3 | kavaratti
# 'coord'
# Processing Record 5 of Set 3 | sitka
# 'coord'
# Processing Record 6 of Set 3 | aweil
# 'coord'
# Processing Record 7 of Set 3 | maintirano
# 'coord'
# Processing Record 8 of Set 3 | papatowai
# 'coord'
# Processing Record 9 of Set 3 | college
# 'coord'
# Processing Record 10 of Set 3 | vilyuchinsk
# 'coord'
# Processing Record 11 of Set 3 | sabzevar
# 'coord'
# Processing Record 12 of Set 3 | kalmunai
# 'coord'
# Processing Record 13 of Set 3 | ancud
# 'coord'
# Processing Record 14 of Set 3 | tura
# 'coord'
# Processing Record 15 of Set 3 | remire-montjoly
# 'coord'
# Processing Record 16 of Set 3 | suncho corral
# 'coord'
# Processing Record 17 of Set 3 | luena
# 'coord'
# Processing Record 18 of Set 3 | lae
# 'coord'
# Processing Record 19 of Set 3 | nelson bay
# 'coord'
# Processing Record 20 of Set 3 | mahajanga
# 'coord'
# Processing Record 21 of Set 3 | avarua
# 'coord'
# Processing Record 22 of Set 3 | machico
# 'coord'
# Processing Record 23 of Set 3 | zaozersk
# 'coord'
# Processing Record 24 of Set 3 | kotri
# 'coord'
# Processing Record 25 of Set 3 | jalai nur
# 'coord'
# Processing Record 26 of Set 3 | al 'alamayn
# 'coord'
# Processing Record 27 of Set 3 | caucete
# 'coord'
# Processing Record 28 of Set 3 | taiohae
# 'coord'
# Processing Record 29 of Set 3 | koneurgench
# 'coord'
# Processing Record 30 of Set 3 | hithadhoo
# 'coord'
# Processing Record 31 of Set 3 | contamana
# 'coord'
# Processing Record 32 of Set 3 | bikin
# 'coord'
# Processing Record 33 of Set 3 | nea michaniona
# 'coord'
# Processing Record 34 of Set 3 | gilgit
# 'coord'
# Processing Record 35 of Set 3 | ararangua
# 'coord'
# Processing Record 36 of Set 3 | maroantsetra
# 'coord'
# Processing Record 37 of Set 3 | springbok
# 'coord'
# Processing Record 38 of Set 3 | cacheu
# 'coord'
# Processing Record 39 of Set 3 | guanica
# 'coord'
# Processing Record 40 of Set 3 | posto fiscal rolim de moura
# 'coord'
# Processing Record 41 of Set 3 | margaret river
# 'coord'
# Processing Record 42 of Set 3 | puerto ayacucho
# 'coord'
# Processing Record 43 of Set 3 | gadzhiyevo
# 'coord'
# Processing Record 44 of Set 3 | itoman
# 'coord'
# Processing Record 45 of Set 3 | urzhum
# 'coord'
# Processing Record 46 of Set 3 | ghat
# 'coord'
# Processing Record 47 of Set 3 | mirnyy
# 'coord'
# Processing Record 48 of Set 3 | yadgir
# 'coord'
# Processing Record 49 of Set 3 | dudinka
# 'coord'
# Processing Record 0 of Set 4 | bethel
# 'coord'
# Processing Record 1 of Set 4 | guna
# 'coord'
# Processing Record 2 of Set 4 | fuvahmulah
# 'coord'
# Processing Record 3 of Set 4 | tolanaro
# 'coord'
# Processing Record 4 of Set 4 | luganville
# 'coord'
# Processing Record 5 of Set 4 | petropavlovsk-kamchatsky
# 'coord'
# Processing Record 6 of Set 4 | belmonte
# 'coord'
# Processing Record 7 of Set 4 | bonthe
# 'coord'
# Processing Record 8 of Set 4 | arraial do cabo
# 'coord'
# Processing Record 9 of Set 4 | san patricio
# 'coord'
# Processing Record 10 of Set 4 | hammerfest
# 'coord'
# Processing Record 11 of Set 4 | nuuk
# 'coord'
# Processing Record 12 of Set 4 | pontianak
# 'coord'
# Processing Record 13 of Set 4 | tokar
# 'coord'
# Processing Record 14 of Set 4 | san antonio de pale
# 'coord'
# Processing Record 15 of Set 4 | haiku-pauwela
# 'coord'
# Processing Record 16 of Set 4 | west island
# 'coord'
# Processing Record 17 of Set 4 | nova sintra
# 'coord'
# Processing Record 18 of Set 4 | moapa valley
# 'coord'
# Processing Record 19 of Set 4 | kulia village
# 'coord'
# Processing Record 20 of Set 4 | port mathurin
# 'coord'
# Processing Record 21 of Set 4 | hermanus
# 'coord'
# Processing Record 22 of Set 4 | badger
# 'coord'
# Processing Record 23 of Set 4 | guillermo zuniga
# 'coord'
# Processing Record 24 of Set 4 | qaqortoq
# 'coord'
# Processing Record 25 of Set 4 | lompoc
# 'coord'
# Processing Record 26 of Set 4 | prince rupert
# 'coord'
# Processing Record 27 of Set 4 | island harbour
# 'coord'
# Processing Record 28 of Set 4 | zeya
# 'coord'
# Processing Record 29 of Set 4 | minot air force base
# 'coord'
# Processing Record 30 of Set 4 | yangor
# 'coord'
# Processing Record 31 of Set 4 | al-`ula
# 'coord'
# Processing Record 32 of Set 4 | luziania
# 'coord'
# Processing Record 33 of Set 4 | qandala
# 'coord'
# Processing Record 34 of Set 4 | guerrero negro
# 'coord'
# Processing Record 35 of Set 4 | fredonia
# 'coord'
# Processing Record 36 of Set 4 | lazaro cardenas
# 'coord'
# Processing Record 37 of Set 4 | playa del ingles
# 'coord'
# Processing Record 38 of Set 4 | ulsteinvik
# 'coord'
# Processing Record 39 of Set 4 | swakopmund
# 'coord'
# Processing Record 40 of Set 4 | kollum
# 'coord'
# Processing Record 41 of Set 4 | carnarvon
# 'coord'
# Processing Record 42 of Set 4 | okhotsk
# 'coord'
# Processing Record 43 of Set 4 | saint-philippe
# 'coord'
# Processing Record 44 of Set 4 | ouellah
# 'coord'
# Processing Record 45 of Set 4 | kodiak
# 'coord'
# Processing Record 46 of Set 4 | saksaul'skiy
# 'coord'
# Processing Record 47 of Set 4 | hotan
# 'coord'
# Processing Record 48 of Set 4 | enewetak
# 'coord'
# Processing Record 49 of Set 4 | fort st. john
# 'coord'
# Processing Record 0 of Set 5 | biltine
# 'coord'
# Processing Record 1 of Set 5 | bac kan
# 'coord'
# Processing Record 2 of Set 5 | aasiaat
# 'coord'
# Processing Record 3 of Set 5 | lerici
# 'coord'
# Processing Record 4 of Set 5 | porto novo
# 'coord'
# Processing Record 5 of Set 5 | namibe
# 'coord'
# Processing Record 6 of Set 5 | bredasdorp
# 'coord'
# Processing Record 7 of Set 5 | bac lieu
# 'coord'
# Processing Record 8 of Set 5 | talnakh
# 'coord'
# Processing Record 9 of Set 5 | al ghayzah
# 'coord'
# Processing Record 10 of Set 5 | mount isa
# 'coord'
# Processing Record 11 of Set 5 | punta arenas
# 'coord'
# Processing Record 12 of Set 5 | fort bragg
# 'coord'
# Processing Record 13 of Set 5 | utrik
# 'coord'
# Processing Record 14 of Set 5 | linxia chengguanzhen
# 'coord'
# Processing Record 15 of Set 5 | sao gabriel da cachoeira
# 'coord'
# Processing Record 16 of Set 5 | castlemaine
# 'coord'
# Processing Record 17 of Set 5 | kokoda
# 'coord'
# Processing Record 18 of Set 5 | soe
# 'coord'
# Processing Record 19 of Set 5 | sinop
# 'coord'
# Processing Record 20 of Set 5 | poli
# 'coord'
# Processing Record 21 of Set 5 | asentamiento humano nicolas de pierola
# 'coord'
# Processing Record 22 of Set 5 | porto cristo
# 'coord'
# Processing Record 23 of Set 5 | richards bay
# 'coord'
# Processing Record 24 of Set 5 | port moresby
# 'coord'
# Processing Record 25 of Set 5 | adh dhibiyah
# 'coord'
# Processing Record 26 of Set 5 | miyanoura
# 'coord'
# Processing Record 27 of Set 5 | gashua
# 'coord'
# Processing Record 28 of Set 5 | vernon
# 'coord'
# Processing Record 29 of Set 5 | checker hall
# 'coord'
# Processing Record 30 of Set 5 | baiti
# 'coord'
# Processing Record 31 of Set 5 | garissa
# 'coord'
# Processing Record 32 of Set 5 | chonchi
# 'coord'
# Processing Record 33 of Set 5 | tsuyama
# 'coord'
# Processing Record 34 of Set 5 | puerto san carlos
# 'coord'
# Processing Record 35 of Set 5 | le port
# 'coord'
# Processing Record 36 of Set 5 | port lincoln
# 'coord'
# Processing Record 37 of Set 5 | pariaman
# 'coord'
# Processing Record 38 of Set 5 | frolovo
# 'coord'
# Processing Record 39 of Set 5 | nar'yan-mar
# 'coord'
# Processing Record 40 of Set 5 | merizo village
# 'coord'
# Processing Record 41 of Set 5 | amfissa
# 'coord'
# Processing Record 42 of Set 5 | port elizabeth
# 'coord'
# Processing Record 43 of Set 5 | tsiombe
# 'coord'
# Processing Record 44 of Set 5 | pyt-yakh
# 'coord'
# Processing Record 45 of Set 5 | kudahuvadhoo
# 'coord'
# Processing Record 46 of Set 5 | lamar
# 'coord'
# Processing Record 47 of Set 5 | neiafu
# 'coord'
# Processing Record 48 of Set 5 | al burayqah
# 'coord'
# Processing Record 49 of Set 5 | sant lluis
# 'coord'
# Processing Record 0 of Set 6 | maymana
# 'coord'
# Processing Record 1 of Set 6 | talara
# 'coord'
# Processing Record 2 of Set 6 | egersund
# 'coord'
# Processing Record 3 of Set 6 | la libertad
# 'coord'
# Processing Record 4 of Set 6 | saltillo
# 'coord'
# Processing Record 5 of Set 6 | taligaman
# 'coord'
# Processing Record 6 of Set 6 | ballycastle
# 'coord'
# Processing Record 7 of Set 6 | kuanda
# 'coord'
# Processing Record 8 of Set 6 | longyearbyen
# 'coord'
# Processing Record 9 of Set 6 | warwick
# 'coord'
# Processing Record 10 of Set 6 | oban
# 'coord'
# Processing Record 11 of Set 6 | palikir - national government center
# 'coord'
# Processing Record 12 of Set 6 | alice springs
# 'coord'
# Processing Record 13 of Set 6 | undurkhaan
# 'coord'
# Processing Record 14 of Set 6 | leshan
# 'coord'
# Processing Record 15 of Set 6 | kalispell
# 'coord'
# Processing Record 16 of Set 6 | crane
# 'coord'
# Processing Record 17 of Set 6 | quellon
# 'coord'
# Processing Record 18 of Set 6 | xam nua
# 'coord'
# Processing Record 19 of Set 6 | siracusa
# 'coord'
# Processing Record 20 of Set 6 | kimbe
# 'coord'
# Processing Record 21 of Set 6 | argo
# 'coord'
# Processing Record 22 of Set 6 | xai-xai
# 'coord'
# Processing Record 23 of Set 6 | yemetsk
# 'coord'
# Processing Record 24 of Set 6 | kiunga
# 'coord'
# Processing Record 25 of Set 6 | fortuna
# 'coord'
# Processing Record 26 of Set 6 | andalgala
# 'coord'
# Processing Record 27 of Set 6 | bikenibeu village
# 'coord'
# Processing Record 28 of Set 6 | ijuw
# 'coord'
# Processing Record 29 of Set 6 | kabalo
# 'coord'
# Processing Record 30 of Set 6 | lai chau
# 'coord'
# Processing Record 31 of Set 6 | puerto lempira
# 'coord'
# Processing Record 32 of Set 6 | saint-jean-de-monts
# 'coord'
# Processing Record 33 of Set 6 | xudat
# 'coord'
# Processing Record 34 of Set 6 | bargaal
# 'coord'
# Processing Record 35 of Set 6 | fauske
# 'coord'
# Processing Record 36 of Set 6 | ksar chellala
# 'coord'
# Processing Record 37 of Set 6 | mormugao
# 'coord'
# Processing Record 38 of Set 6 | banda aceh
# 'coord'
# Processing Record 39 of Set 6 | kavieng
# 'coord'
# Processing Record 40 of Set 6 | st. john's
# 'coord'
# Processing Record 41 of Set 6 | hyesan
# 'coord'
# Processing Record 42 of Set 6 | flin flon
# 'coord'
# Processing Record 43 of Set 6 | de aar
# 'coord'
# Processing Record 44 of Set 6 | kuvshinovo
# 'coord'
# Processing Record 45 of Set 6 | selfoss
# 'coord'
# Processing Record 46 of Set 6 | badiyah
# 'coord'
# Processing Record 47 of Set 6 | tyuratam
# 'coord'
# Processing Record 48 of Set 6 | ghadamis
# 'coord'
# Processing Record 49 of Set 6 | constantia
# 'coord'
# Processing Record 0 of Set 7 | darnah
# 'coord'
# Processing Record 1 of Set 7 | aykhal
# 'coord'
# Processing Record 2 of Set 7 | numaligarh
# 'coord'
# Processing Record 3 of Set 7 | azemmour
# 'coord'
# Processing Record 4 of Set 7 | chokwe
# 'coord'
# Processing Record 5 of Set 7 | forest
# 'coord'
# Processing Record 6 of Set 7 | namdrik
# 'coord'
# Processing Record 7 of Set 7 | glubokoye
# 'coord'
# Processing Record 8 of Set 7 | broome
# 'coord'
# Processing Record 9 of Set 7 | isangel
# 'coord'
# Processing Record 10 of Set 7 | la passe
# 'coord'
# Processing Record 11 of Set 7 | pamandzi
# 'coord'
# Processing Record 12 of Set 7 | waingapu
# 'coord'
# Processing Record 13 of Set 7 | acapulco de juarez
# 'coord'
# Processing Record 14 of Set 7 | milazzo
# 'coord'
# Processing Record 15 of Set 7 | geneina
# 'coord'
# Processing Record 16 of Set 7 | bubaque
# 'coord'
# Processing Record 17 of Set 7 | turinsk
# 'coord'
# Processing Record 18 of Set 7 | tanjung pinang
# 'coord'
# Processing Record 19 of Set 7 | envira
# 'coord'
# Processing Record 20 of Set 7 | ta`u
# 'coord'
# Processing Record 21 of Set 7 | yuncheng
# 'coord'
# Processing Record 22 of Set 7 | huanuni
# 'coord'
# Processing Record 23 of Set 7 | srandakan
# 'coord'
# Processing Record 24 of Set 7 | little cayman
# 'coord'
# Processing Record 25 of Set 7 | errachidia
# 'coord'
# Processing Record 26 of Set 7 | choyr
# 'coord'
# Processing Record 27 of Set 7 | coruripe
# 'coord'
# Processing Record 28 of Set 7 | sirte
# 'coord'
# Processing Record 29 of Set 7 | bokhan
# 'coord'
# Processing Record 30 of Set 7 | afaahiti
# 'coord'
# Processing Record 31 of Set 7 | sinjar
# 'coord'
# Processing Record 32 of Set 7 | svetlyy
# 'coord'
# Processing Record 33 of Set 7 | kayes
# 'coord'
# Processing Record 34 of Set 7 | uruacu
# 'coord'
# Processing Record 35 of Set 7 | les cayes
# 'coord'
# Processing Record 36 of Set 7 | klaksvik
# 'coord'
# Processing Record 37 of Set 7 | colonia
# 'coord'
# Processing Record 38 of Set 7 | pisco
# 'coord'
# Processing Record 39 of Set 7 | zavodoukovsk
# 'coord'
# Processing Record 40 of Set 7 | changyon
# 'coord'
# Processing Record 41 of Set 7 | castro
# 'coord'
# Processing Record 42 of Set 7 | hadibu
# 'coord'
# Processing Record 43 of Set 7 | alamogordo
# 'coord'
# Processing Record 44 of Set 7 | beipiao
# 'coord'
# Processing Record 45 of Set 7 | naze
# 'coord'
# Processing Record 46 of Set 7 | hobyo
# 'coord'
# Processing Record 47 of Set 7 | kete krachi
# 'coord'
# Processing Record 48 of Set 7 | thunder bay
# 'coord'
# Processing Record 49 of Set 7 | alofi
# 'coord'
# Processing Record 0 of Set 8 | jaisalmer
# 'coord'
# Processing Record 1 of Set 8 | oak island
# 'coord'
# Processing Record 2 of Set 8 | stornoway
# 'coord'
# Processing Record 3 of Set 8 | daru
# 'coord'
# Processing Record 4 of Set 8 | rio de janeiro
# 'coord'
# Processing Record 5 of Set 8 | dnipro
# 'coord'
# Processing Record 6 of Set 8 | barretos
# 'coord'
# Processing Record 7 of Set 8 | dubovka
# 'coord'
# Processing Record 8 of Set 8 | solanea
# 'coord'
# Processing Record 9 of Set 8 | klyuchi
# 'coord'
# Processing Record 10 of Set 8 | vyshniy volochek
# 'coord'
# Processing Record 11 of Set 8 | bardai
# 'coord'
# Processing Record 12 of Set 8 | pizarro
# 'coord'
# Processing Record 13 of Set 8 | newman
# 'coord'
# Processing Record 14 of Set 8 | camano
# 'coord'
# Processing Record 15 of Set 8 | san pedro pochutla
# 'coord'
# Processing Record 16 of Set 8 | markovo
# 'coord'
# Processing Record 17 of Set 8 | torghay
# 'coord'
# Processing Record 18 of Set 8 | kourou
# 'coord'
# Processing Record 19 of Set 8 | cozumel
# 'coord'
# Processing Record 20 of Set 8 | callao
# 'coord'
# Processing Record 21 of Set 8 | ciudad lazaro cardenas
# 'coord'
# Processing Record 22 of Set 8 | nagqu
# 'coord'
# Processing Record 23 of Set 8 | viseu
# 'coord'
# Processing Record 24 of Set 8 | al hada
# 'coord'
# Processing Record 25 of Set 8 | arno
# 'coord'
# Processing Record 26 of Set 8 | paranaiba
# 'coord'
# Processing Record 27 of Set 8 | fale old settlement
# 'coord'
# Processing Record 28 of Set 8 | barinitas
# 'coord'
# Processing Record 29 of Set 8 | mount gambier
# 'coord'
# Processing Record 30 of Set 8 | lata
# 'coord'
# Processing Record 31 of Set 8 | sinabang
# 'coord'
# Processing Record 32 of Set 8 | ebon
# 'coord'
# Processing Record 33 of Set 8 | ust-nera
# 'coord'
# Processing Record 34 of Set 8 | alotau
# 'coord'
# Processing Record 35 of Set 8 | medvezh'yegorsk
# 'coord'
# Processing Record 36 of Set 8 | ambon
# 'coord'
# Processing Record 37 of Set 8 | hayma'
# 'coord'
# Processing Record 38 of Set 8 | bandon
# 'coord'
# Processing Record 39 of Set 8 | yuzhno-kurilsk
# 'coord'
# Processing Record 40 of Set 8 | poronaysk
# 'coord'
# Processing Record 41 of Set 8 | touros
# 'coord'
# Processing Record 42 of Set 8 | howrah
# 'coord'
# Processing Record 43 of Set 8 | vingt cinq
# 'coord'
# Processing Record 44 of Set 8 | gebeit
# 'coord'
# Processing Record 45 of Set 8 | makurazaki
# 'coord'
# Processing Record 46 of Set 8 | saipan
# 'coord'
# Processing Record 47 of Set 8 | baymak
# 'coord'
# Processing Record 48 of Set 8 | arteaga
# 'coord'
# Processing Record 49 of Set 8 | nenagh
# 'coord'
# Processing Record 0 of Set 9 | pedernales
# 'coord'
# Processing Record 1 of Set 9 | okahandja
# 'coord'
# Processing Record 2 of Set 9 | oualidia
# 'coord'
# Processing Record 3 of Set 9 | pantai cenang
# 'coord'
# Processing Record 4 of Set 9 | calingasta
# 'coord'
# Processing Record 5 of Set 9 | manicaragua
# 'coord'
# Processing Record 6 of Set 9 | colchani
# 'coord'
# Processing Record 7 of Set 9 | tazacorte
# 'coord'
# Processing Record 8 of Set 9 | ahau
# 'coord'
# Processing Record 9 of Set 9 | san ignacio
# 'coord'
# Processing Record 10 of Set 9 | hasaki
# 'coord'
# Processing Record 11 of Set 9 | prado
# 'coord'
# Processing Record 12 of Set 9 | pali
# 'coord'
# Processing Record 13 of Set 9 | stevensville
# 'coord'
# Processing Record 14 of Set 9 | juru
# 'coord'
# Processing Record 15 of Set 9 | myeik
# 'coord'
# Processing Record 16 of Set 9 | liberal
# 'coord'
# Processing Record 17 of Set 9 | dunedin
# 'coord'
# Processing Record 18 of Set 9 | gaalkacyo
# 'coord'
# Processing Record 19 of Set 9 | villa angela
# 'coord'
# Processing Record 20 of Set 9 | dengzhou
# 'coord'
# Processing Record 21 of Set 9 | port saint john's
# 'coord'
# Processing Record 22 of Set 9 | severo-yeniseyskiy
# 'coord'
# Processing Record 23 of Set 9 | trairi
# 'coord'
# Processing Record 24 of Set 9 | zhongshu
# 'coord'
# Processing Record 25 of Set 9 | jabor
# 'coord'
# Processing Record 26 of Set 9 | bamboo flat
# 'coord'
# Processing Record 27 of Set 9 | n'diareme limamoulaye
# 'coord'
# Processing Record 28 of Set 9 | porto murtinho
# 'coord'
# Processing Record 29 of Set 9 | reserva
# 'coord'
# Processing Record 30 of Set 9 | ayr
# 'coord'
# Processing Record 31 of Set 9 | anjozorobe
# 'coord'
# Processing Record 32 of Set 9 | hihifo
# 'coord'
# Processing Record 33 of Set 9 | slany
# 'coord'
# Processing Record 34 of Set 9 | nizhnesortymskiy
# 'coord'
# Processing Record 35 of Set 9 | vila franca do campo
# 'coord'
# Processing Record 36 of Set 9 | saki
# 'coord'
# Processing Record 37 of Set 9 | pacific grove
# 'coord'
# Processing Record 38 of Set 9 | yeroham
# 'coord'
# Processing Record 39 of Set 9 | ust-tsilma
# 'coord'
# Processing Record 40 of Set 9 | guixi
# 'coord'
# Processing Record 41 of Set 9 | bosansko grahovo
# 'coord'
# Processing Record 42 of Set 9 | xunchang
# 'coord'
# Processing Record 43 of Set 9 | arvayheer
# 'coord'
# Processing Record 44 of Set 9 | batangafo
# 'coord'
# Processing Record 45 of Set 9 | belyy yar
# 'coord'
# Processing Record 46 of Set 9 | al mutayrifi
# 'coord'
# Processing Record 47 of Set 9 | vilyuysk
# 'coord'
# Processing Record 48 of Set 9 | tenenkou
# 'coord'
# Processing Record 49 of Set 9 | itaituba
# 'coord'
# Processing Record 0 of Set 10 | ust'-ilimsk
# 'coord'
# Processing Record 1 of Set 10 | arkadak
# 'coord'
# Processing Record 2 of Set 10 | sola
# 'coord'
# Processing Record 3 of Set 10 | exeter
# 'coord'
# Processing Record 4 of Set 10 | priargunsk
# 'coord'
# Processing Record 5 of Set 10 | miguel ahumada
# 'coord'
# Processing Record 6 of Set 10 | duong dong
# 'coord'
# Processing Record 7 of Set 10 | nemuro
# 'coord'
# Processing Record 8 of Set 10 | cidreira
# 'coord'
# Processing Record 9 of Set 10 | pudasjarvi
# 'coord'
# Processing Record 10 of Set 10 | karditsa
# 'coord'
# Processing Record 11 of Set 10 | antonio enes
# 'coord'
# Processing Record 12 of Set 10 | zhangye
# 'coord'
# Processing Record 13 of Set 10 | jamiltepec
# 'coord'
# Processing Record 14 of Set 10 | geraldton
# 'coord'
# Processing Record 15 of Set 10 | ouadda
# 'coord'
# Processing Record 16 of Set 10 | karratha
# 'coord'
# Processing Record 17 of Set 10 | ghogha
# 'coord'
# Processing Record 18 of Set 10 | amga
# 'coord'
# Processing Record 19 of Set 10 | isle of lewis
# 'coord'
# Processing Record 20 of Set 10 | ban lam luk ka
# 'coord'
# Processing Record 21 of Set 10 | aljezur
# 'coord'
# Processing Record 22 of Set 10 | alto barinas
# 'coord'
# Processing Record 23 of Set 10 | campo maior
# 'coord'
# Processing Record 24 of Set 10 | sittwe
# 'coord'
# Processing Record 25 of Set 10 | pemangkat
# 'coord'
# Processing Record 26 of Set 10 | wolmaransstad
# 'coord'
# Processing Record 27 of Set 10 | roma
# 'coord'
# Processing Record 28 of Set 10 | altai
# 'coord'
# Processing Record 29 of Set 10 | karbala
# 'coord'
# Processing Record 30 of Set 10 | rudnya
# 'coord'
# Processing Record 31 of Set 10 | ati
# 'coord'
# Processing Record 32 of Set 10 | bhind
# 'coord'
# Processing Record 33 of Set 10 | kerikeri
# 'coord'
# Processing Record 34 of Set 10 | tangalle
# 'coord'
# Processing Record 35 of Set 10 | baihar
# 'coord'
# Processing Record 36 of Set 10 | okha
# 'coord'
# Processing Record 37 of Set 10 | ipojuca
# 'coord'
# Processing Record 38 of Set 10 | sechura
# 'coord'
# Processing Record 39 of Set 10 | east london
# 'coord'
# Processing Record 40 of Set 10 | flying fish cove
# 'coord'
# Processing Record 41 of Set 10 | bereket
# 'coord'
# Processing Record 42 of Set 10 | juneau
# 'coord'
# Processing Record 43 of Set 10 | komatipoort
# 'coord'
# Processing Record 44 of Set 10 | pucon
# 'coord'
# Processing Record 45 of Set 10 | bu'aale
# 'coord'
# Processing Record 46 of Set 10 | kharkhorin
# 'coord'
# Processing Record 47 of Set 10 | vanimo
# 'coord'
# Processing Record 48 of Set 10 | ciudad acuna
# 'coord'
# Processing Record 49 of Set 10 | san jose
# 'coord'
# Processing Record 0 of Set 11 | cooper's town
# 'coord'
# Processing Record 1 of Set 11 | kirakira
# 'coord'
# Processing Record 2 of Set 11 | al marj
# 'coord'
# Processing Record 3 of Set 11 | leninskoye
# 'coord'
# Processing Record 4 of Set 11 | mogocha
# 'coord'
# Processing Record 5 of Set 11 | taroa
# 'coord'
# Processing Record 6 of Set 11 | luanshya
# 'coord'
# Processing Record 7 of Set 11 | marka
# 'coord'
# Processing Record 8 of Set 11 | shiyan
# 'coord'
# Processing Record 9 of Set 11 | derbent
# 'coord'
# Processing Record 10 of Set 11 | maloye ganyushkino
# 'coord'
# Processing Record 11 of Set 11 | puerto baquerizo moreno
# 'coord'
# Processing Record 12 of Set 11 | luderitz
# 'coord'
# Processing Record 13 of Set 11 | gao
# 'coord'
# Processing Record 14 of Set 11 | dschang
# 'coord'
# Processing Record 15 of Set 11 | minot
# 'coord'
# Processing Record 16 of Set 11 | quelimane
# 'coord'
# Processing Record 17 of Set 11 | sandnessjoen
# 'coord'
# Processing Record 18 of Set 11 | chui
# 'coord'
# Processing Record 19 of Set 11 | laurel
# 'coord'
# Processing Record 20 of Set 11 | mukah
# 'coord'
# Processing Record 21 of Set 11 | funadhoo
# 'coord'
# Processing Record 22 of Set 11 | katsuura
# 'coord'
# Processing Record 23 of Set 11 | lerwick
# 'coord'
# Processing Record 24 of Set 11 | saint-paul
# 'coord'
# Processing Record 25 of Set 11 | yarmouth
# 'coord'
# Processing Record 26 of Set 11 | khandyga
# 'coord'
# Processing Record 27 of Set 11 | nykobing mors
# 'coord'
# Processing Record 28 of Set 11 | strezhevoy
# 'coord'
# Processing Record 29 of Set 11 | al bayda'
# 'coord'
# Processing Record 30 of Set 11 | tocopilla
# 'coord'
# Processing Record 31 of Set 11 | kozova
# 'coord'
# Processing Record 32 of Set 11 | queenstown
# 'coord'
# Processing Record 33 of Set 11 | camana
# 'coord'
# Processing Record 34 of Set 11 | cill airne
# 'coord'
# Processing Record 35 of Set 11 | puerto lleras
# 'coord'
# Processing Record 36 of Set 11 | galliano
# 'coord'
# Processing Record 37 of Set 11 | fada n'gourma
# 'coord'
# Processing Record 38 of Set 11 | shimoda
# 'coord'
# Processing Record 39 of Set 11 | horta
# 'coord'
# Processing Record 40 of Set 11 | belel
# 'coord'
# Processing Record 41 of Set 11 | kibondo
# 'coord'
# Processing Record 42 of Set 11 | brezina
# 'coord'
# Processing Record 43 of Set 11 | nuku'alofa
# 'coord'
# Processing Record 44 of Set 11 | cidade velha
# 'coord'
# Processing Record 45 of Set 11 | kailua-kona
# 'coord'
# Processing Record 46 of Set 11 | novo selo
# 'coord'
# Processing Record 47 of Set 11 | metlili chaamba
# 'coord'
# Processing Record 48 of Set 11 | vila velha
# 'coord'
# Processing Record 49 of Set 11 | villers-cotterets
# 'coord'
# Processing Record 0 of Set 12 | lachhmangarh sikar
# 'coord'
# Processing Record 1 of Set 12 | bhamo
# 'coord'
# Processing Record 2 of Set 12 | tofol
# 'coord'
# Processing Record 3 of Set 12 | amet
# 'coord'
# Processing Record 4 of Set 12 | uturoa
# 'coord'
# Processing Record 5 of Set 12 | kruisfontein
# 'coord'
# Processing Record 6 of Set 12 | espargos
# 'coord'
# Processing Record 7 of Set 12 | reggane
# 'coord'
# Processing Record 8 of Set 12 | matoury
# 'coord'
# Processing Record 9 of Set 12 | yoichi
# 'coord'
# Processing Record 10 of Set 12 | pineville
# 'coord'
# Processing Record 11 of Set 12 | mahanoro
# 'coord'
# Processing Record 12 of Set 12 | laojunmiao
# 'coord'
# Processing Record 13 of Set 12 | labrador city
# 'coord'
# Processing Record 14 of Set 12 | igarka
# 'coord'
# Processing Record 15 of Set 12 | umm kaddadah
# 'coord'
# Processing Record 16 of Set 12 | margate
# 'coord'
# Processing Record 17 of Set 12 | tulln
# 'coord'
# Processing Record 18 of Set 12 | sumenep
# 'coord'
# Processing Record 19 of Set 12 | ixtapa
# 'coord'
# Processing Record 20 of Set 12 | el colomo
# 'coord'
# Processing Record 21 of Set 12 | boyolangu
# 'coord'
# Processing Record 22 of Set 12 | santa cruz
# 'coord'
# Processing Record 23 of Set 12 | upata
# 'coord'
# Processing Record 24 of Set 12 | tidjikja
# 'coord'
# Processing Record 25 of Set 12 | nema
# 'coord'
# Processing Record 26 of Set 12 | farah
# 'coord'
# Processing Record 27 of Set 12 | sao vicente
# 'coord'
# Processing Record 28 of Set 12 | tanout
# 'coord'
# Processing Record 29 of Set 12 | bengkulu
# 'coord'
# Processing Record 30 of Set 12 | boone
# 'coord'
# Processing Record 31 of Set 12 | ciudad bolivar
# 'coord'
# Processing Record 32 of Set 12 | walvis bay
# 'coord'
# Processing Record 33 of Set 12 | cargados carajos
# 'coord'
# Processing Record 34 of Set 12 | sanctuary point
# 'coord'
# Processing Record 35 of Set 12 | barabai
# 'coord'
# Processing Record 36 of Set 12 | macae
# 'coord'
# Processing Record 37 of Set 12 | atherton
# 'coord'
# Processing Record 38 of Set 12 | huarmey
# 'coord'
# Processing Record 39 of Set 12 | ilebo
# 'coord'
# Processing Record 40 of Set 12 | usogorsk
# 'coord'
# Processing Record 41 of Set 12 | shambu
# 'coord'
# Processing Record 42 of Set 12 | puke
# 'coord'
# Processing Record 43 of Set 12 | severnoye
# 'coord'
# Processing Record 44 of Set 12 | arawa
# 'coord'
# Processing Record 45 of Set 12 | barroquinha
# 'coord'
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)


# Show Record Count
city_data_df.count()
# Out:
# Series([], dtype: int64)

# %%
city_data_df = pd.DataFrame({
    "City": city,
    "Lat": city_lat,
    "Lng": city_lng,
    "Max Temp": city_max_temp,
    "Humidity": city_humidity,
    "Cloudiness": city_clouds,
    "Wind Speed": city_wind,
    "Country": city_country,
    "Date": city_data
    })
city_data_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\osman\BootCampClass\homework\Python-api-challenge\WeatherPy (1).ipynb Cell 9 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/osman/BootCampClass/homework/Python-api-challenge/WeatherPy%20%281%29.ipynb#X56sZmlsZQ%3D%3D?line=0'>1</a> city_data_df = pd.DataFrame({
#       <a href='vscode-notebook-cell:/c%3A/Users/osman/BootCampClass/homework/Python-api-challenge/WeatherPy%20%281%29.ipynb#X56sZmlsZQ%3D%3D?line=1'>2</a>     "City": city,
# ----> <a href='vscode-notebook-cell:/c%3A/Users/osman/BootCampClass/homework/Python-api-challenge/WeatherPy%20%281%29.ipynb#X56sZmlsZQ%3D%3D?line=2'>3</a>     "Lat": city_lat,
#       <a href='vscode-notebook-cell:/c%3A/Users/osman/BootCampClass/homework/Python-api-challenge/WeatherPy%20%281%29.ipynb#X56sZmlsZQ%3D%3D?line=3'>4</a>     "Lng": city_lng,
#       <a href='vscode-notebook-cell:/c%3A/Users/osman/BootCampClass/homework/Python-api-challenge/WeatherPy%20%281%29.ipynb#X56sZmlsZQ%3D%3D?line=4'>5</a>     "Max Temp": city_max_temp,
#       <a href='vscode-notebook-cell:/c%3A/Users/osman/BootCampClass/homework/Python-api-challenge/WeatherPy%20%281%29.ipynb#X56sZmlsZQ%3D%3D?line=5'>6</a>     "Humidity": city_humidity,
#       <a href='vscode-notebook-cell:/c%3A/Users/osman/BootCampClass/homework/Python-api-challenge/WeatherPy%20%281%29.ipynb#X56sZmlsZQ%3D%3D?line=6'>7</a>     "Cloudiness": city_clouds,
#       <a href='vscode-notebook-cell:/c%3A/Users/osman/BootCampClass/homework/Python-api-challenge/WeatherPy%20%281%29.ipynb#X56sZmlsZQ%3D%3D?line=7'>8</a>     "Wind Speed": city_wind,
#       <a href='vscode-notebook-cell:/c%3A/Users/osman/BootCampClass/homework/Python-api-challenge/WeatherPy%20%281%29.ipynb#X56sZmlsZQ%3D%3D?line=8'>9</a>     "Country": city_country,
#      <a href='vscode-notebook-cell:/c%3A/Users/osman/BootCampClass/homework/Python-api-challenge/WeatherPy%20%281%29.ipynb#X56sZmlsZQ%3D%3D?line=9'>10</a>     "Date": city_data
#      <a href='vscode-notebook-cell:/c%3A/Users/osman/BootCampClass/homework/Python-api-challenge/WeatherPy%20%281%29.ipynb#X56sZmlsZQ%3D%3D?line=10'>11</a>     })
#      <a href='vscode-notebook-cell:/c%3A/Users/osman/BootCampClass/homework/Python-api-challenge/WeatherPy%20%281%29.ipynb#X56sZmlsZQ%3D%3D?line=11'>12</a> city_data_df.head()
#
# NameError: name 'city_lat' is not defined

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# Series([], dtype: int64)

# %%
# Display sample data
city_data_df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(     
    city_data_df["Lat"],
    city_data_df["Max Temp"],
    edgecolor="black",
    linewidths=1,
    marker="o", 
    alpha=0.8,
    label="Cities"
)

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Temperature (%s)" % time.strftime("%Y-%m-%d"))
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(     
    city_data_df["Lat"],
    city_data_df["Humidity"],
    edgecolor="black",
    linewidths=1,
    marker="o", 
    alpha=0.8,
    label="Cities"
)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%Y-%m-%d"))
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Cloudiness"],
    edgecolor="black",
    linewidths=1,
    marker="o", 
    alpha=0.8,
    label="Cities"
)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%Y-%m-%d"))
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(
    city_data_df["Lat"], 
    city_data_df["Wind Speed"],
    edgecolor="black", 
    linewidths=1, 
    marker="o", 
    alpha=0.8,
    label="Cities"
)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%Y-%m-%d"))
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, text_coordinates):
    
    # Compute linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    # Plot
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize=15,color="red")
    plt.xlabel("Latitude")
    plt.ylabel(title)
    print(f"The r-value is: {rvalue**2}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]

# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        kiri buru  22.0833   85.3500     16.61        39          60
# 1         yabluniv  48.4042   24.9387     -0.83        58         100
# 13            hope  33.6671  -93.5916      6.03        92         100
# 14           kapit   2.0167  112.9333     22.96        99         100
# 15        chunoyar  57.4467   97.3217    -22.17       100         100
#
#          Wind Speed Country        Date
# City_ID
# 0              0.69      IN  1675107385
# 1              2.70      UA  1675107387
# 13             3.38      US  1675107274
# 14             0.53      MY  1675107394
# 15             1.54      RU  1675107395

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2             rikitea -23.1203 -134.9692     25.87        72           5
# 3               bluff -46.6000  168.3333     14.40        89         100
# 4        puerto ayora  -0.7393  -90.3518     29.98        87         100
# 5             ushuaia -54.8000  -68.3000     10.79        62          40
# 6           busselton -33.6500  115.3333     15.53        83         100
#
#          Wind Speed Country        Date
# City_ID
# 2              3.46      PF  1675106596
# 3              2.38      NZ  1675106876
# 4              3.58      EC  1675106670
# 5             11.32      AR  1675106620
# 6              6.93      AU  1675106633

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Max Temp",(6,-10))
# Out:
# The r-value is: 0.7087748626712942

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Max Temp", (-55, 35))
# Out:
# The r-value is: 0.2223060001834937

# %% [markdown]
# **Discussion about the linear relationship:** The high `r` value indicates a strong positive correlation between latitude and max temperature. R values ~ 0.5 indicate that there is a moderate positive correlation.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Humidity",(40,10))
# Out:
# The r-value is: 0.2454747100804553

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Humidity", (-50, 20))
# Out:
# The r-value is: 0.028443175559542205

# %% [markdown]
# **Discussion about the linear relationship:** The low `r` values indicate a weak to no relationship between humidity and latitude.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, "Cloudiness", (40,10))
# Out:
# The r-value is: 0.15487412383192467

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, "Cloudiness", (-30,30))
# Out:
# The r-value is: 0.07715389597083025

# %% [markdown]
# **Discussion about the linear relationship:** The low `r` values indicate a weak positive relationship between latitude and cloudiness.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, "Wind Speed", (10,12))
# Out:
# The r-value is: 0.021451695951846293

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, "Wind Speed", (-50, 12))
# Out:
# The r-value is: 0.09599014302772504

# %% [markdown]
# **Discussion about the linear relationship:** The low `r` values indicate that there is no real relationship between wind speed and latitude. The difference between the hemispheres doesn't seem to be significant enough to comment upon.
